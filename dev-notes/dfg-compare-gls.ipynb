# %%
from am4pa.linnea import LinneaConfig, MeasurementsLinnea
import pandas as pd
from variants_compare import VariantsCompare
from pm4py.objects.conversion.log import converter as log_converter
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
linnea_config = LinneaConfig("GLS",4)
linnea_config.set_local_directory("linnea/GLS/")

# %%
op_sizes = ["1000","230"]
ms = MeasurementsLinnea(linnea_config,op_sizes)
ms.generate_variants(bGenerate=False)
dc = ms.data_collector
df = dc.get_meta_table()

# %%
df
# Out:
#     case:concept:name           concept:name  concept:flops  \
# 0         algorithm36            transpose_1            1.0
# 1         algorithm36  LAPACK.potrf_3.33e+08    333000000.0
# 2         algorithm36           trsm_2.3e+08    230000000.0
# 3         algorithm36             trsv_1e+06      1000000.0
# 4         algorithm36          syrk_5.29e+07     52900000.0
# ..                ...                    ...            ...
# 919       algorithm44             trsv_1e+06      1000000.0
# 920       algorithm44      ml4 = qr_3.24e+07     32400000.0
# 921       algorithm44           gemv_4.6e+05       460000.0
# 922       algorithm44          gemv_1.06e+05       106000.0
# 923       algorithm44          trsv_5.29e+04        52900.0
#
#                                concept:kernel        concept:operation  \
# 0                        transpose!(ml3, ml0)              tmp56 = X^T
# 1                     LAPACK.potrf!('L', ml1)            (L2 L2^T) = M
# 2    trsm!('L', 'L', 'N', 'N', 1.0, ml1, ml0)        tmp12 = (L2^-1 X)
# 3              trsv!('L', 'N', 'N', ml1, ml2)        tmp68 = (L2^-1 y)
# 4         syrk!('L', 'T', 1.0, ml0, 0.0, ml4)  tmp14 = (tmp12^T tmp12)
# ..                                        ...                      ...
# 919            trsv!('L', 'T', 'N', ml1, ml2)    tmp71 = (L2^-T tmp68)
# 920                            ml4 = qr!(ml4)        (Q16 R17) = tmp14
# 921       gemv!('N', 1.0, ml3, ml2, 0.0, ml5)    tmp21 = (tmp56 tmp71)
# 922       gemv!('T', 1.0, ml6, ml5, 0.0, ml7)    tmp25 = (Q16^T tmp21)
# 923            trsv!('U', 'N', 'N', ml8, ml7)   tmp24 = (R17^-1 tmp25)
#
#                 timestamp:start
# 0    2022-12-21 19:45:06.090288
# 1    2022-12-21 19:45:07.090288
# 2    2022-12-21 19:45:08.090288
# 3    2022-12-21 19:45:09.090288
# 4    2022-12-21 19:45:10.090288
# ..                          ...
# 919  2022-12-21 19:58:31.090288
# 920  2022-12-21 19:58:32.090288
# 921  2022-12-21 19:58:33.090288
# 922  2022-12-21 19:58:34.090288
# 923  2022-12-21 19:58:35.090288
#
# [924 rows x 6 columns]

# %%
xes_log = log_converter.apply(df)

# %%
for t in xes_log:
    for e in t:
        print(e['concept:name'],'(or)', e['concept:operation'])
    break
# Out:
# transpose_1 (or) tmp56 = X^T
# LAPACK.potrf_3.33e+08 (or) (L2 L2^T) = M
# trsm_2.3e+08 (or) tmp12 = (L2^-1 X)
# trsv_1e+06 (or) tmp68 = (L2^-1 y)
# syrk_5.29e+07 (or) tmp14 = (tmp12^T tmp12)
# ml4 = qr_3.24e+07 (or) (Q16 R17) = tmp14
# trsv_1e+06 (or) tmp71 = (L2^-T tmp68)
# gemv_4.6e+05 (or) tmp21 = (tmp56 tmp71)
# gemv_1.06e+05 (or) tmp25 = (Q16^T tmp21)
# trsv_5.29e+04 (or) tmp24 = (R17^-1 tmp25)

# %%
all_vars = list(df['case:concept:name'].unique())
best = ['algorithm0', 'algorithm1']
worst = ['algorithm3', 'algorithm4']
# worst = all_vars.copy()
# for v in best:
#     worst.remove(v)

activity_key = 'concept:name'
#activity_key = 'concept:operation'

# %%
vc = VariantsCompare(xes_log,best,worst,activity_key=activity_key)
# Out:
# /Users/aravind/.local/lib/python3.9/site-packages/pm4py/utils.py:486: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")

# %%
vc.show_petrinet(best,activity_key=activity_key)

# %%
vc.show_petrinet(worst,activity_key=activity_key)
# Out:
# /Users/aravind/.local/lib/python3.9/site-packages/pm4py/utils.py:486: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")

# %%
vc.get_dfg_minus_best()
# Out:
# /Users/aravind/.local/lib/python3.9/site-packages/pm4py/utils.py:486: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")
